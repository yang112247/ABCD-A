# %% [markdown]
# <a href="https://colab.research.google.com/github/yang112247/ABCD-A/blob/20250317/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4/3
# Out:
# 1.3333333333333333

# %%
1/2
# Out:
# 0.5

# %%
4/2
# Out:
# 2.0

# %%
7//3
# Out:
# 2

# %%
7%3
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
int(5 / 2)
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
a = 11 + 2
b = 12 - 2
c = 13 * 2
d = 14 / 2
e = 15 ** 2
f = 16 // 2
g = 17 % 3
print(a, b, c, d, e, f, g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
divmod(5, 2)
# Out:
# (2, 1)

# %%
puotient, remainder = divmod (5, 2)
print(puotient, remainder)
# Out:
# 2 1

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *= 2
print(i)
i /= 2
print(int (i))
i = 3
i %= 2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *= 2
print(i)
i /= 2
print(int (i))
i = 3
i %= 2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a == b)
print("10 != 3 =>", a != b)
print("10 > = 3 =>", a > b)
print("10 >= 3 =>", a >= b)
print("10 < 3 =>", a < b)
print("10 <= 3 =>", a <= b)
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > = 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
bin(18)
# Out:
# '0b10010'

# %%
0b10010
# Out:
# 18

# %%
a = 18
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b10010
# 0b1001
# 0b0
# 0

# %%
a = 18
b = 9
print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)
# Out:
# 0b10010
# 0b1001
# 0b11011
# 27

# %%
a = 12
b = 8
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 0b1100
# 0b1000
# 0b100
#
# 4

# %%
a = 12
b = 8
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101
