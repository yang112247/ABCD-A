# %% [markdown]
# <a href="https://colab.research.google.com/github/yang112247/ABCD-A/blob/20250314/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문자열 출력

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# 중간에 ' 가있는 문자열 출력

# %%
print("'Mary's cosmetics")
# Out:
# 'Mary's cosmetics

# %% [markdown]
# 중간에 " 가있는 문자열 출력

# %%
print('신씨가 소리를 질렀다. "도둑이야."')
# Out:
# 신씨가 소리를 질렀다. "도둑이야."

# %% [markdown]
# c:\windows 출력

# %%
print( "c:\\windows")
# Out:
# c:\windows

# %% [markdown]
# \n(줄바꿈) 과 \t(텝) 열할

# %%
print("안녕하세요. \n만나서 \t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서 		반갑습니다.

# %% [markdown]
# 여러 데이터 출력

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %% [markdown]
# print 기초 기능

# %%
print("naver" ,"kakao","samsung", sep =';')
# Out:
# naver;kakao;samsung

# %%
print("naver" ,"kakao","samsung", sep ='/')
# Out:
# naver/kakao/samsung

# %% [markdown]
# 한줄의 명령어 2개의 명령어 2줄의 결과물

# %%
print("first");print ("second")
# Out:
# first
# second

# %% [markdown]
# 연산 결과 출력

# %%
print(5/3)
# Out:
# 1.6666666666666667
